# %%
import pandas as pd
import numpy as np

train = pd.read_csv("~/data/uba.csv",error_bad_lines=False)
# Out:
# /home/aakp/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,4,5,8,9,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head()
# Out:
#   ActivityID               ProcessName      ApplicationName TotalSeconds  \
# 0    7726490                SYSTEMLOCK  2018-01-29 22:01:18           20
# 1    7726491              SYSTEMUNLOCK  2018-01-29 22:01:38           20
# 2    7726492              EXPLORER.EXE      PROGRAM MANAGER           40
# 3    7726493  APPLICATIONFRAMEHOST.EXE             SETTINGS           60
# 4    7726494              EXPLORER.EXE             UBA CODE           20
#
#   LapsedSeconds ApplFocusInterval      currentWindowsIdentity  \
# 0            20                 0  ANBGLOBALDC/samarendra.jee
# 1            14                 6  ANBGLOBALDC/samarendra.jee
# 2             0                40  ANBGLOBALDC/samarendra.jee
# 3             4                56  ANBGLOBALDC/samarendra.jee
# 4             0                20  ANBGLOBALDC/samarendra.jee
#
#   IsUserPartOfAdminGroup IntegrityLevel Recordings     ...      \
# 0                    NaN            NaN        NaN     ...
# ...

# %%
train
# Out:
#        ActivityID               ProcessName  \
# 0         7726490                SYSTEMLOCK
# 1         7726491              SYSTEMUNLOCK
# 2         7726492              EXPLORER.EXE
# 3         7726493  APPLICATIONFRAMEHOST.EXE
# 4         7726494              EXPLORER.EXE
# 5         7726486               FIREFOX.EXE
# 6         7726487               FIREFOX.EXE
# 7         7726488               FIREFOX.EXE
# 8         7726489               FIREFOX.EXE
# 9         7726483               FIREFOX.EXE
# 10        7726484               FIREFOX.EXE
# 11        7726485               FIREFOX.EXE
# 12        7726482               FIREFOX.EXE
# 13        7726479               FIREFOX.EXE
# 14        7726480               FIREFOX.EXE
# 15        7726481               FIREFOX.EXE
# 16        7726475              EXPLORER.EXE
# 17        7726476              ACRORD32.EXE
# 18        7726477               FIREFOX.EXE
# 19        7726478               FIREFOX.EXE
# ...

# %%
clean_data = train['Unnamed: 15' ]
clean_data.shape
# Out:
# (145300,)

# %%
index=[]
for i,j in enumerator(clean_data):
    if j=="NaN":
        index[i]=True
    else :
        index[i]=False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-bba87926ae06> in <module>()
#       1 index=[]
# ----> 2 for i,j in enumerator(clean_data):
#       3     if j=="NaN":
#       4         index[i]=True
#       5     else :
#
# NameError: name 'enumerator' is not defined

# %%
print(train[~np.isnan(train).any(axis=1)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-3e8b9e5cfade> in <module>()
# ----> 1 print(train[~np.isnan(train).any(axis=1)])
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df = train[[train['Unnamed: 15'][i] != "NaN" for i in range(145300)]  ]

# %%
df
# Out:
#        ActivityID               ProcessName  \
# 0         7726490                SYSTEMLOCK
# 1         7726491              SYSTEMUNLOCK
# 2         7726492              EXPLORER.EXE
# 3         7726493  APPLICATIONFRAMEHOST.EXE
# 4         7726494              EXPLORER.EXE
# 5         7726486               FIREFOX.EXE
# 6         7726487               FIREFOX.EXE
# 7         7726488               FIREFOX.EXE
# 8         7726489               FIREFOX.EXE
# 9         7726483               FIREFOX.EXE
# 10        7726484               FIREFOX.EXE
# 11        7726485               FIREFOX.EXE
# 12        7726482               FIREFOX.EXE
# 13        7726479               FIREFOX.EXE
# 14        7726480               FIREFOX.EXE
# 15        7726481               FIREFOX.EXE
# 16        7726475              EXPLORER.EXE
# 17        7726476              ACRORD32.EXE
# 18        7726477               FIREFOX.EXE
# 19        7726478               FIREFOX.EXE
# ...

# %%
xyz = [isinstance(train['Unnamed: 15'][i], float)  for i in range(145300)]

# %%
import re
def hasNumbers(inputString):
    return bool(re.search(r'\d', inputString))
for i in range(145300):
    print(train['Unnamed: 15'][i],hasNumbers(train['Unnamed: 15'][i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-313252585c6b> in <module>()
#       3     return bool(re.search(r'\d', inputString))
#       4 for i in range(145300):
# ----> 5     print(train['Unnamed: 15'][i],hasNumbers(train['Unnamed: 15'][i]))
#       6
#       7 train['Unnamed: 15'][0]
#
# <ipython-input-49-313252585c6b> in hasNumbers(inputString)
#       1 import re
#       2 def hasNumbers(inputString):
# ----> 3     return bool(re.search(r'\d', inputString))
#       4 for i in range(145300):
#       5     print(train['Unnamed: 15'][i],hasNumbers(train['Unnamed: 15'][i]))
#
# /usr/lib/python3.6/re.py in search(pattern, string, flags)
#     180     """Scan through string looking for a match to the pattern, returning
#     181     a match object, or None if no match was found."""
# --> 182     return _compile(pattern, flags).search(string)
#     183
# ...

# %%
xyz
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
train2 = train[xyz]
print(train2)
# Out:
#        ActivityID               ProcessName  \
# 0         7726490                SYSTEMLOCK
# 1         7726491              SYSTEMUNLOCK
# 2         7726492              EXPLORER.EXE
# 3         7726493  APPLICATIONFRAMEHOST.EXE
# 4         7726494              EXPLORER.EXE
# 5         7726486               FIREFOX.EXE
# 6         7726487               FIREFOX.EXE
# 7         7726488               FIREFOX.EXE
# 8         7726489               FIREFOX.EXE
# 9         7726483               FIREFOX.EXE
# 11        7726485               FIREFOX.EXE
# 12        7726482               FIREFOX.EXE
# 13        7726479               FIREFOX.EXE
# 14        7726480               FIREFOX.EXE
# 15        7726481               FIREFOX.EXE
# 16        7726475              EXPLORER.EXE
# 17        7726476              ACRORD32.EXE
# 18        7726477               FIREFOX.EXE
# 19        7726478               FIREFOX.EXE
# 20        7726473               FIREFOX.EXE
# ...

# %%
totalsecs = [train2['TotalSeconds'][i]=="NaN"  for i in range(145206)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-cf9e35a84792> in <module>()
# ----> 1 totalsecs = [train2['TotalSeconds'][i]=="NaN"  for i in range(145206)]
#
# <ipython-input-59-cf9e35a84792> in <listcomp>(.0)
# ----> 1 totalsecs = [train2['TotalSeconds'][i]=="NaN"  for i in range(145206)]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
# ...

# %%
print([train2['TotalSeconds'][i]=="NaN"  for i in range(145206)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-9735cd957398> in <module>()
# ----> 1 print([train2['TotalSeconds'][i]=="NaN"  for i in range(145206)])
#
# <ipython-input-61-9735cd957398> in <listcomp>(.0)
# ----> 1 print([train2['TotalSeconds'][i]=="NaN"  for i in range(145206)])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
# ...

# %%
for i in range(145206):
    print(train2['TotalSeconds'],train2['TotalSeconds']=="NaN")

# %%
train3 =  train2.dropna(subset=['TotalSeconds'])
print(train3)
# Out:
#        ActivityID               ProcessName  \
# 0         7726490                SYSTEMLOCK
# 1         7726491              SYSTEMUNLOCK
# 2         7726492              EXPLORER.EXE
# 3         7726493  APPLICATIONFRAMEHOST.EXE
# 4         7726494              EXPLORER.EXE
# 5         7726486               FIREFOX.EXE
# 6         7726487               FIREFOX.EXE
# 7         7726488               FIREFOX.EXE
# 8         7726489               FIREFOX.EXE
# 9         7726483               FIREFOX.EXE
# 11        7726485               FIREFOX.EXE
# 12        7726482               FIREFOX.EXE
# 13        7726479               FIREFOX.EXE
# 14        7726480               FIREFOX.EXE
# 15        7726481               FIREFOX.EXE
# 16        7726475              EXPLORER.EXE
# 17        7726476              ACRORD32.EXE
# 18        7726477               FIREFOX.EXE
# 19        7726478               FIREFOX.EXE
# 20        7726473               FIREFOX.EXE
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-292e7a8533f1> in <module>()
# ----> 1 train4 = train3.drop(['Unnamed: 15'],inplace = True)
#       2 train4
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
train = pd.read_csv("~/data/clean.csv",error_bad_lines=False)
# Out:
# /home/aakp/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,4,5,6,8,9,10,13,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train3 = train.drop(columns=['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21'])
train3
train3.to_csv('~/data/clean.csv')

# %%
train = pd.read_csv("~/data/clean.csv",error_bad_lines=False)
# Out:
# /home/aakp/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,5,6,7,9,10,11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train
# Out:
#         Unnamed: 0  Unnamed: 0.1 ActivityID               ProcessName  \
# 0                0             0    7726490                SYSTEMLOCK
# 1                1             1    7726491              SYSTEMUNLOCK
# 2                2             2    7726492              EXPLORER.EXE
# 3                3             3    7726493  APPLICATIONFRAMEHOST.EXE
# 4                4             4    7726494              EXPLORER.EXE
# 5                5             5    7726486               FIREFOX.EXE
# 6                6             6    7726487               FIREFOX.EXE
# 7                7             7    7726488               FIREFOX.EXE
# 8                8             8    7726489               FIREFOX.EXE
# 9                9             9    7726483               FIREFOX.EXE
# 10              10            11    7726485               FIREFOX.EXE
# 11              11            12    7726482               FIREFOX.EXE
# ...

# %%
uniqueProcessName = train.ProcessName.unique()

# %%
uniqueProcessName
# Out:
# array(['SYSTEMLOCK', 'SYSTEMUNLOCK', 'EXPLORER.EXE',
#        'APPLICATIONFRAMEHOST.EXE', 'FIREFOX.EXE', 'ACRORD32.EXE',
#        'DEVENV.EXE', 'CHROME.EXE', 'SHELLEXPERIENCEHOST.EXE',
#        'NOTEPAD.EXE', 'STIKYNOT.EXE', 'SPOPRT.EXE', 'OUTLOOK.EXE',
#        'EXCEL.EXE', 'NITROPDF.EXE', ' ', 'SSMS.EXE', 'VMWARE.EXE',
#        'MSTSC.EXE', 'ENCRYPTION.EXE', 'IEXPLORE.EXE', 'WINWORD.EXE',
#        'DWM.EXE', 'ATMGR.EXE', 'SCREENPRESSO.EXE',
#        'ARCOSSERVERMANAGER.EXE', 'POTPLAYERMINI64.EXE', 'ET.EXE',
#        'CODEDUITESTBUILDER.EXE', 'POWERPNT.EXE', 'SQLDEVELOPERW.EXE',
#        'SNAGIT32.EXE', 'SNAGITEDITOR.EXE', 'CMD.EXE', 'VIRTUALBOX.EXE',
#        'SUBLIME_TEXT.EXE', 'DLLHOST.EXE', 'TASKMGR.EXE', 'DW20.EXE',
#        'MCUICNT.EXE', 'CONFIGURATIONWIZARD.EXE', 'SKYPE.EXE',
#        'CAMTASIASTUDIO.EXE', 'TORTOISEPROC.EXE', 'MMC.EXE', 'CALC.EXE',
#        'ELECTRON.EXE', 'CISCOWEBEXSTART.EXE', 'IGFXEM.EXE',
# ...

# %%
ProcessCount =  train.ProcessName.value_counts()

# %%
ProcessCount
# Out:
# CHROME.EXE                                                   52680
# EXPLORER.EXE                                                 21477
# FIREFOX.EXE                                                  12842
# OUTLOOK.EXE                                                   6814
# IEXPLORE.EXE                                                  5557
# DEVENV.EXE                                                    4833
# EXCEL.EXE                                                     4361
# WINWORD.EXE                                                   4292
# ACRORD32.EXE                                                  2143
# SSMS.EXE                                                      2117
# MSTSC.EXE                                                     2032
# POWERPNT.EXE                                                  1988
# ARCOSSERVERMANAGER.EXE                                        1859
# ATMGR.EXE                                                     1691
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
train.ProcessName.value_counts().plot(ax=ax, kind='bar')

# %%
train.ProcessName.value_counts().hist()

# %%
newprocessCode=train.ProcessName.astype("category", categories=uniqueProcessName).cat.codes
# Out:
# /home/aakp/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   """Entry point for launching an IPython kernel.

# %%
train['ProcessName'] = newprocessCode

# %%
train = train.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
train
# Out:
#        ActivityID  ProcessName  \
# 0         7726490            0
# 1         7726491            1
# 2         7726492            2
# 3         7726493            3
# 4         7726494            2
# 5         7726486            4
# 6         7726487            4
# 7         7726488            4
# 8         7726489            4
# 9         7726483            4
# 10        7726485            4
# 11        7726482            4
# 12        7726479            4
# 13        7726480            4
# 14        7726481            4
# 15        7726475            2
# 16        7726476            5
# 17        7726477            4
# 18        7726478            4
# 19        7726473            4
# 20        7726474            2
# 21        7726469            4
# 22        7726470            4
# 23        7726471            0
# 24        7726472            1
# 25        7726467            6
# 26        7726468            4
# 27        7726466            1
# 28        7726463            1
# ...
